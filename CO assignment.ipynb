# %% [markdown]
# # COLUMN OPERATIONS

# %% [markdown]
# ABOUT THE DATASET

# %% [markdown]
# My dataset is downloaded from kaggle dataset website for column operations using pandas. This data is about Adidas sales information around the world with region wise from 2022 to 2021.

# %%
 import pandas as pd

# %% [markdown]
# To perform the operations we need to import a library, so here pandas is imported as pd.

# %%
data=pd.read_csv("C://Users//admin//Downloads//archive (2)//AdidasDatasets.csv")

# %% [markdown]
# read_csv function is used to read the data in jupiter notebook.

# %%
data
# Out:
#          Retailer  Retailer ID Invoice Date     Region          State  \
# 0     Foot Locker      1185732   01-01-2020  Northeast       New York
# 1     Foot Locker      1185732   02-01-2020  Northeast       New York
# 2     Foot Locker      1185732   03-01-2020  Northeast       New York
# 3     Foot Locker      1185732   04-01-2020  Northeast       New York
# 4     Foot Locker      1185732   05-01-2020  Northeast       New York
# ...           ...          ...          ...        ...            ...
# 9643  Foot Locker      1185732   24-01-2021  Northeast  New Hampshire
# 9644  Foot Locker      1185732   24-01-2021  Northeast  New Hampshire
# 9645  Foot Locker      1185732   22-02-2021  Northeast  New Hampshire
# 9646  Foot Locker      1185732   22-02-2021  Northeast  New Hampshire
# 9647  Foot Locker      1185732   22-02-2021  Northeast  New Hampshire
#
#             City                    Product  Price per Unit  Units Sold  \
# ...

# %% [markdown]
# I named data as a name to my dataset to view.

# %%
data['Operating Margin']=data['Total Sales']/data['Operating Profit']*100

# %% [markdown]
# The variable operating margin is calculated by total sales divided by operating profit into 100.

# %%
data.rename(columns={'Total Sales':'Sales'})
# Out:
#          Retailer  Retailer ID Invoice Date     Region          State  \
# 0     Foot Locker      1185732   01-01-2020  Northeast       New York
# 1     Foot Locker      1185732   02-01-2020  Northeast       New York
# 2     Foot Locker      1185732   03-01-2020  Northeast       New York
# 3     Foot Locker      1185732   04-01-2020  Northeast       New York
# 4     Foot Locker      1185732   05-01-2020  Northeast       New York
# ...           ...          ...          ...        ...            ...
# 9643  Foot Locker      1185732   24-01-2021  Northeast  New Hampshire
# 9644  Foot Locker      1185732   24-01-2021  Northeast  New Hampshire
# 9645  Foot Locker      1185732   22-02-2021  Northeast  New Hampshire
# 9646  Foot Locker      1185732   22-02-2021  Northeast  New Hampshire
# 9647  Foot Locker      1185732   22-02-2021  Northeast  New Hampshire
#
#             City                    Product  Price per Unit  Units Sold  \
# ...

# %% [markdown]
# The variable Total Sales is renamed as Sales.

# %%
data.drop(['State','Product'],axis=1)
# Out:
#          Retailer  Retailer ID Invoice Date     Region        City  \
# 0     Foot Locker      1185732   01-01-2020  Northeast    New York
# 1     Foot Locker      1185732   02-01-2020  Northeast    New York
# 2     Foot Locker      1185732   03-01-2020  Northeast    New York
# 3     Foot Locker      1185732   04-01-2020  Northeast    New York
# 4     Foot Locker      1185732   05-01-2020  Northeast    New York
# ...           ...          ...          ...        ...         ...
# 9643  Foot Locker      1185732   24-01-2021  Northeast  Manchester
# 9644  Foot Locker      1185732   24-01-2021  Northeast  Manchester
# 9645  Foot Locker      1185732   22-02-2021  Northeast  Manchester
# 9646  Foot Locker      1185732   22-02-2021  Northeast  Manchester
# 9647  Foot Locker      1185732   22-02-2021  Northeast  Manchester
#
#       Price per Unit  Units Sold  Total Sales  Operating Profit  \
# 0                 50        1200       600000            300000
# ...

# %% [markdown]
# Dropping(deleting) the variable State and product from the dataset.

# %%
data.columns=[col.upper()for col in data.columns]
data
# Out:
#          RETAILER  RETAILER ID INVOICE DATE     REGION          STATE  \
# 0     Foot Locker      1185732   01-01-2020  Northeast       New York
# 1     Foot Locker      1185732   02-01-2020  Northeast       New York
# 2     Foot Locker      1185732   03-01-2020  Northeast       New York
# 3     Foot Locker      1185732   04-01-2020  Northeast       New York
# 4     Foot Locker      1185732   05-01-2020  Northeast       New York
# ...           ...          ...          ...        ...            ...
# 9643  Foot Locker      1185732   24-01-2021  Northeast  New Hampshire
# 9644  Foot Locker      1185732   24-01-2021  Northeast  New Hampshire
# 9645  Foot Locker      1185732   22-02-2021  Northeast  New Hampshire
# 9646  Foot Locker      1185732   22-02-2021  Northeast  New Hampshire
# 9647  Foot Locker      1185732   22-02-2021  Northeast  New Hampshire
#
#             CITY                    PRODUCT  PRICE PER UNIT  UNITS SOLD  \
# ...

# %% [markdown]
# Changing all variables names completely in uppercase.

# %%
data.columns=[col.lower()for col in data.columns]
data
# Out:
#          retailer  retailer id invoice date     region          state  \
# 0     Foot Locker      1185732   01-01-2020  Northeast       New York
# 1     Foot Locker      1185732   02-01-2020  Northeast       New York
# 2     Foot Locker      1185732   03-01-2020  Northeast       New York
# 3     Foot Locker      1185732   04-01-2020  Northeast       New York
# 4     Foot Locker      1185732   05-01-2020  Northeast       New York
# ...           ...          ...          ...        ...            ...
# 9643  Foot Locker      1185732   24-01-2021  Northeast  New Hampshire
# 9644  Foot Locker      1185732   24-01-2021  Northeast  New Hampshire
# 9645  Foot Locker      1185732   22-02-2021  Northeast  New Hampshire
# 9646  Foot Locker      1185732   22-02-2021  Northeast  New Hampshire
# 9647  Foot Locker      1185732   22-02-2021  Northeast  New Hampshire
#
#             city                    product  price per unit  units sold  \
# ...

# %% [markdown]
# Changing all variables names completely in lowercase.

# %%
data.sort_values(by='units sold',ascending=True)
# Out:
#          retailer  retailer id invoice date     region     state      city  \
# 1025  Foot Locker      1185732   11-06-2021    Midwest  Nebraska     Omaha
# 1019  Foot Locker      1185732   05-06-2021    Midwest  Nebraska     Omaha
# 4913  Foot Locker      1185732   11-06-2021    Midwest  Nebraska     Omaha
# 4907  Foot Locker      1185732   05-06-2021    Midwest  Nebraska     Omaha
# 4914  Foot Locker      1185732   12-06-2021    Midwest  Nebraska     Omaha
# ...           ...          ...          ...        ...       ...       ...
# 24    Foot Locker      1185732   06-02-2020  Northeast  New York  New York
# 30    Foot Locker      1185732   04-03-2020  Northeast  New York  New York
# 42    Foot Locker      1185732   16-03-2020  Northeast  New York  New York
# 6     Foot Locker      1185732   07-01-2020  Northeast  New York  New York
# 36    Foot Locker      1185732   10-03-2020  Northeast  New York  New York
#
# ...

# %% [markdown]
# Arranging units sold variable in ascending order.

# %%
data.groupby('retailer id').count()
# Out:
#              invoice date  region  state  city  product  price per unit  \
# retailer id
# 1128299              2370    2370   2370  2370     2370            2370
# 1185732              5265    5265   5265  5265     5265            5265
# 1189833               360     360    360   360      360             360
# 1197831              1653    1653   1653  1653     1653            1653
#
#              units sold  total sales  operating profit  operating margin  \
# retailer id
# 1128299            2370         2370              2370              2370
# 1185732            5265         5265              5265              5261
# 1189833             360          360               360               360
# 1197831            1653         1653              1653              1653
#
#              sales method
# retailer id
# 1128299              2370
# 1185732              5265
# 1189833               360
# 1197831              1653

# %% [markdown]
# Counting sales with respective retailer id.

# %%
print(data['retailer id'].isnull().sum())
# Out:
# 0

# %% [markdown]
# This variables contains no null values.

# %%
print(data.columns.values)
# Out:
# ['retailer id' 'invoice date' 'region' 'state' 'city' 'product'
#  'price per unit' 'units sold' 'total sales' 'operating profit'
#  'operating margin' 'sales method']

# %% [markdown]
# This function is used to print all variables names.

# %%
print(len(data.columns.values))
# Out:
# 12

# %% [markdown]
# The count of total number of variables
